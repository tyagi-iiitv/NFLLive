# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
import glob
from sklearn import preprocessing
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 6)

# %%
km = KMeans(n_clusters=1800, n_jobs=-1)

# %%
data = pd.read_csv('data/full_data.csv')

# %%
X = data

# %%
min_max_scalar = preprocessing.MinMaxScaler()

# %%
X[['TimeSecsClass','DownClass','yrdline100Class','FavScoreDiffClass']] = min_max_scalar.fit_transform(data[['TimeSecsClass','DownClass','yrdline100Class','FavScoreDiffClass']])

# %%
Y = data[['Prob']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.6, random_state=42)

# %%
km.fit(X_train[['TimeSecsClass','DownClass','yrdline100Class','FavScoreDiffClass']], y_train)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/tyagi/NFLLive/env/lib/python3.4/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 350, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/tyagi/NFLLive/env/lib/python3.4/site-packages/sklearn/externals/joblib/parallel.py", line 131, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/home/tyagi/NFLLive/env/lib/python3.4/site-packages/sklearn/externals/joblib/parallel.py", line 131, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/home/tyagi/NFLLive/env/lib/python3.4/site-packages/sklearn/cluster/k_means_.py", line 400, in _kmeans_single_elkan
#     max_iter=max_iter, verbose=verbose)
# ...
